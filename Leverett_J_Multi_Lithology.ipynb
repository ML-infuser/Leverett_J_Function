# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('ee4.xlsx',header = None)
df2 = pd.read_excel('gg6.xlsx',header = None)
df3 = pd.read_excel('ii8.xlsx',header = None)
df4 = pd.read_excel('o10.xlsx',header = None)
df5 = pd.read_excel('oo9.xlsx',header = None)
df6 = pd.read_excel('rr5.xlsx',header = None)
df7 = pd.read_excel('rr5.xlsx',header = None)
df8 = pd.read_excel('sss3.xlsx',header = None)
df9 = pd.read_excel('sw1.xlsx',header = None)
df10 = pd.read_excel('sw2.xlsx',header = None)
df11 = pd.read_excel('uu7.xlsx',header = None)

# %%
df1
# Out:
#            0         1
# 0   100.0000  0.000026
# 1    99.1115  0.000046
# 2    98.5889  0.000067
# 3    97.3341  0.000102
# 4    95.3477  0.000163
# 5    83.2732  0.000264
# 6    40.8700  0.000425
# 7    29.4748  0.000651
# 8    24.4044  0.001015
# 9    20.3071  0.001642
# 10   17.4689  0.002606
# 11   15.0545  0.004238
# 12   13.1097  0.006521
# 13   11.6140  0.010215
# 14   10.5585  0.016245
# 15    9.7523  0.026582
# 16    9.0460  0.042753
# 17    8.3355  0.065238
# 18    7.4958  0.101378
# 19    6.5154  0.163404
# 20    5.6177  0.265870
# 21    5.2152  0.361603
# 22    4.7784  0.427589
# 23    4.1673  0.671870

# %%
x1 = np.array(df1.iloc[:,0])
y1 = np.array(df1.iloc[:,1])
x2 = np.array(df2.iloc[:,0])
y2 = np.array(df2.iloc[:,1])
x3 = np.array(df3.iloc[:,0])
y3 = np.array(df3.iloc[:,1])
x4 = np.array(df4.iloc[:,0])
y4 = np.array(df4.iloc[:,1])
x5 = np.array(df5.iloc[:,0])
y5 = np.array(df5.iloc[:,1])
x6 = np.array(df6.iloc[:,0])
y6 = np.array(df6.iloc[:,1])
x7 = np.array(df7.iloc[:,0])
y7 = np.array(df7.iloc[:,1])
x8 = np.array(df8.iloc[:,0])
y8 = np.array(df8.iloc[:,1])
x9 = np.array(df9.iloc[:,0])
y9 = np.array(df9.iloc[:,1])
x10 = np.array(df10.iloc[:,0])
y10 = np.array(df10.iloc[:,1])
x11 = np.array(df11.iloc[:,0])
y11 = np.array(df11.iloc[:,1])

# %%
plt.xlabel('Sw (Wetting-Phase-Saturation % )')
plt.ylabel('J ( Leverett-J-func )')
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)
plt.plot(x5,y5)
plt.plot(x6,y6)
plt.plot(x7,y7)
plt.plot(x8,y8)
plt.plot(x9,y9)
plt.plot(x10,y10)
plt.plot(x11,y11)
plt.show()
